# %% [markdown]
# # 1) Create a pandas dataframe (DataFrame name as 'df') with numpy random values 4 features and 4 observation

# %%
import pandas as pd
import numpy as np
import random
df=pd.DataFrame(np.random.rand(4,4))
df
# Out:
#           0         1         2         3
# 0  0.420060  0.077483  0.052943  0.460775
# 1  0.652113  0.439324  0.439927  0.058825
# 2  0.853360  0.870432  0.580143  0.732540
# 3  0.368952  0.722843  0.209369  0.173347

# %% [markdown]
# # 2) Rename the task - 1 'df' dataframe column names to 'Random value 1', 'Random value 2', 'Random value 3' & 'Random value 4

# %%
df.columns=['Random value 1','Random value 2','Random value 3','Random value 4']
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.420060        0.077483        0.052943        0.460775
# 1        0.652113        0.439324        0.439927        0.058825
# 2        0.853360        0.870432        0.580143        0.732540
# 3        0.368952        0.722843        0.209369        0.173347

# %% [markdown]
# # 3) Find the descriptive statistics of the 'df' dataframe

# %%
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.573622        0.527520        0.320595        0.356372
# std          0.223521        0.349309        0.234957        0.302453
# min          0.368952        0.077483        0.052943        0.058825
# 25%          0.407283        0.348864        0.170262        0.144717
# 50%          0.536087        0.581083        0.324648        0.317061
# 75%          0.702425        0.759740        0.474981        0.528716
# max          0.853360        0.870432        0.580143        0.732540

# %% [markdown]
# # 4) Check for the null values in 'df' and find the data type of the columns

# %%
print(df.info())
df.isnull().any()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Random value 1  4 non-null      float64
#  1   Random value 2  4 non-null      float64
#  2   Random value 3  4 non-null      float64
#  3   Random value 4  4 non-null      float64
# dtypes: float64(4)
# memory usage: 256.0 bytes
# None
# Random value 1    False
# Random value 2    False
# Random value 3    False
# Random value 4    False
# dtype: bool

# %% [markdown]
# # 5) Display the 'Random value 2' & 'Random value 3' columns with location method and index location method

# %%
print(df.loc[0:3,'Random value 2':'Random value 3'])
df.iloc[0:4,1:3]
# Out:
#    Random value 2  Random value 3
# 0        0.077483        0.052943
# 1        0.439324        0.439927
# 2        0.870432        0.580143
# 3        0.722843        0.209369
#    Random value 2  Random value 3
# 0        0.077483        0.052943
# 1        0.439324        0.439927
# 2        0.870432        0.580143
# 3        0.722843        0.209369
