# %% [markdown]
# # 1) Download the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("/content/penguins_size.csv")
print(df.shape)
# Out:
# (344, 7)

# %% [markdown]
# #  2) Load the dataset into the tool

# %%
df=pd.read_csv("/content/penguins_size.csv")
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %% [markdown]
# # 3. Perform Below Visualizations.
# 1) Univariate Analysis
# 2) Bi- Variate Analysis
# 3) Multi-Variate Analysis

# %%
#Univaraite
sns.distplot(df['culmen_length_mm'])
plt.show()
sns.scatterplot(df['flipper_length_mm'])
plt.show()

count = df['island'].value_counts()
int_values = count.values
plt.pie(count,labels=df['island'].unique(),autopct="%1.1f%%",explode=[0.1,0.1,0.1],shadow=True)
plt.show()
# Out:
# <ipython-input-3-098e0da55801>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['culmen_length_mm'])

# %%
#Bivariate
sns.lineplot(x=df['culmen_length_mm'],y=df['body_mass_g'])
plt.show()
sns.scatterplot(x=df['culmen_depth_mm'],y=df['culmen_length_mm'])
plt.show()
sns.jointplot(x=df['culmen_depth_mm'],y=df['culmen_length_mm'])
sns.jointplot(x=df['culmen_length_mm'],y=df['body_mass_g'])

# %%
#Multivariate
sns.pairplot(df)

# %% [markdown]
# # 4) Perform descriptive statistics on the dataset

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %% [markdown]
# # 5) Check for Missing values and deal with them

# %%
df.isnull()
# Out:
#      species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0      False   False             False            False              False
# 1      False   False             False            False              False
# 2      False   False             False            False              False
# 3      False   False              True             True               True
# 4      False   False             False            False              False
# ..       ...     ...               ...              ...                ...
# 339    False   False              True             True               True
# 340    False   False             False            False              False
# 341    False   False             False            False              False
# 342    False   False             False            False              False
# 343    False   False             False            False              False
#
#      body_mass_g    sex
# 0          False  False
# ...

# %%
df.isna().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
#Nan values replaced with median for non categorical columns
#culmen_length_mm column
df['culmen_length_mm'].fillna(df['culmen_length_mm'].median(),inplace=True)
#culmen_depth_mm column
df['culmen_depth_mm'].fillna(df['culmen_depth_mm'].median(), inplace = True )
#flipper_length_mm column
df['flipper_length_mm'].fillna(df['flipper_length_mm'].median(), inplace = True )
#body_mass_g
df['body_mass_g'].fillna(df['body_mass_g'].median(), inplace = True )

#Nan values replaced with mode for categorical columns(SEX)
print(df['sex'].mode())
df['sex'].fillna("MALE",inplace=True)
df.isna().any()
# Out:
# 0    MALE
# Name: sex, dtype: object
# species              False
# island               False
# culmen_length_mm     False
# culmen_depth_mm      False
# flipper_length_mm    False
# body_mass_g          False
# sex                  False
# dtype: bool

# %%
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %% [markdown]
# # 6)Find the outliers and replace them outliers

# %%
non_categorical_columns = df.select_dtypes(exclude=['object'])
for column in non_categorical_columns.columns:
    sns.boxplot(data=df,x=column)
    plt.title(f'Boxplot for {column}')
    plt.show()

# %% [markdown]
# # 7) Check the correlation of independent variables with the target

# %%
# here the correlation is performed after encoding the traget varaible coz correlation can't be calculated on categorical column
print(df.corr(numeric_only=True))# overall correlation
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
#                     species    island  culmen_length_mm  culmen_depth_mm  \
# species            1.000000 -0.635659          0.731369        -0.744076
# island            -0.635659  1.000000         -0.353647         0.571035
# culmen_length_mm   0.731369 -0.353647          1.000000        -0.235053
# culmen_depth_mm   -0.744076  0.571035         -0.235053         1.000000
# flipper_length_mm  0.854307 -0.565825          0.656181        -0.583851
# body_mass_g        0.750491 -0.561515          0.595110        -0.471916
# sex               -0.010379  0.043476          0.269434         0.322860
#
#                    flipper_length_mm  body_mass_g       sex
# species                     0.854307     0.750491 -0.010379
# island                     -0.565825    -0.561515  0.043476
# culmen_length_mm            0.656181     0.595110  0.269434
# culmen_depth_mm            -0.583851    -0.471916  0.322860
# flipper_length_mm           1.000000     0.871202  0.197440
# ...

# %% [markdown]
# # 8) Check for Categorical columns and perform encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

df['species']=le.fit_transform(df['species'])
df['sex']=le.fit_transform(df['sex'])
df['island']=le.fit_transform(df['island'])
df
# Out:
#      species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0          0       2              39.1             18.7              181.0
# 1          0       2              39.5             17.4              186.0
# 2          0       2              40.3             18.0              195.0
# 3          0       2               NaN              NaN                NaN
# 4          0       2              36.7             19.3              193.0
# ..       ...     ...               ...              ...                ...
# 339        2       0               NaN              NaN                NaN
# 340        2       0              46.8             14.3              215.0
# 341        2       0              50.4             15.7              222.0
# 342        2       0              45.2             14.8              212.0
# 343        2       0              49.9             16.1              213.0
#
#      body_mass_g  sex
# 0         3750.0    2
# ...

# %%
df.corr(numeric_only=True).species.sort_values(ascending=False)
# Out:
# species              1.000000
# flipper_length_mm    0.854307
# body_mass_g          0.750491
# culmen_length_mm     0.731369
# sex                 -0.010379
# island              -0.635659
# culmen_depth_mm     -0.744076
# Name: species, dtype: float64

# %% [markdown]
# # 9) Split the data into dependent and independent variables.

# %%
x=df.drop(columns='species',axis=1)
x
# Out:
#      island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0         2              39.1             18.7              181.0
# 1         2              39.5             17.4              186.0
# 2         2              40.3             18.0              195.0
# 3         2               NaN              NaN                NaN
# 4         2              36.7             19.3              193.0
# ..      ...               ...              ...                ...
# 339       0               NaN              NaN                NaN
# 340       0              46.8             14.3              215.0
# 341       0              50.4             15.7              222.0
# 342       0              45.2             14.8              212.0
# 343       0              49.9             16.1              213.0
#
#      body_mass_g  sex
# 0         3750.0    2
# 1         3800.0    1
# 2         3250.0    1
# 3            NaN    3
# 4         3450.0    1
# ..           ...  ...
# ...

# %%
y=df['species']
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 339    2
# 340    2
# 341    2
# 342    2
# 343    2
# Name: species, Length: 344, dtype: int64

# %% [markdown]
# # 10) Scaling the data

# %%
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()
x_sc=pd.DataFrame(sc.fit_transform(x),columns=x.columns)
x_sc
# Out:
#      island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0       1.0          0.254545         0.666667           0.152542
# 1       1.0          0.269091         0.511905           0.237288
# 2       1.0          0.298182         0.583333           0.389831
# 3       1.0               NaN              NaN                NaN
# 4       1.0          0.167273         0.738095           0.355932
# ..      ...               ...              ...                ...
# 339     0.0               NaN              NaN                NaN
# 340     0.0          0.534545         0.142857           0.728814
# 341     0.0          0.665455         0.309524           0.847458
# 342     0.0          0.476364         0.202381           0.677966
# 343     0.0          0.647273         0.357143           0.694915
#
#      body_mass_g       sex
# 0       0.291667  0.666667
# 1       0.305556  0.333333
# 2       0.152778  0.333333
# 3            NaN  1.000000
# 4       0.208333  0.333333
# ...

# %% [markdown]
# # 11) Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_sc,y,test_size=0.2,random_state=0)

# %% [markdown]
# # 12) Check the training and testing data shape.

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (275, 6)
# (275,)
# (69, 6)
# (69,)
